# %% [markdown]
# # I. SIMPLE LINEAR REGRESSION

# %% [markdown]
# - Sử dụng câu lệnh "pip install scikit-learn và matplotlib" trong Powershell để cài đặt thư viện để triển khai các mô hình học máy và matplotlib để vẽ đồ thị và trực quan hóa dữ liệu

# %% [markdown]
# Below table represents current home prices in monroe township based on square feet area, new jersey

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Problem Statement**: Given above data build a machine learning model that can predict home prices based on square feet area

# %% [markdown]
# You can represent values in above table as a scatter plot(values are shown in red markers). After that one can draw a straight line that best fits values on chart.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can draw multuple lines like this but we choose the one where total sum of error is minimum

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker = '+')

# %%
new_df=df.drop('price',axis='columns')
#Tách area ra làm biến độc lập
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
#Tạo mô hình hồi quy tuyến tính
reg = linear_model.LinearRegression()
reg.fit(new_df,price) #Tương đương với x_train (biến độc lập) và y_train(biến phụ thuộc)
# Out:
# LinearRegression()

# %%
reg.predict([[1000]])
# Out:
# c:\Users\ad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([316404.10958904])

# %%
reg.coef_ #X
# Out:
# array([135.78767123])

# %%
reg.intercept_ #b
# Out:
# np.float64(180616.43835616432)

# %% [markdown]
# **Y = m*X + b ( X is coefficient and b is intercept )**

# %% [markdown]
# **(1)** Predict price of a home with area = 5000 sqr ft

# %%
reg.predict([[500]])
# Out:
# c:\Users\ad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([248510.2739726])

# %% [markdown]
#     - Generate CSV File with list of home price predictions

# %%
area_df = pd.read_csv("area.csv")
area_df.head(3)
# Out:
#    area
# 0  2295
# 1  2323
# 2  3966

# %%
p = reg.predict(area_df)
p
# Out:
# array([492249.14383562, 496051.19863014, 719150.34246575, 738839.55479452,
#        275532.02054795, 444995.03424658, 572907.02054795, 671624.65753425,
#        635505.1369863 , 513839.38356164, 491841.78082192, 449883.39041096,
#        275260.44520548, 369904.45205479, 266977.39726027, 552267.29452055,
#        554983.04794521, 437526.71232877, 712768.32191781, 271322.60273973,
#        635776.71232877, 828595.20547945, 460474.82876712, 848555.99315068,
#        317490.4109589 , 681129.79452055, 489804.96575342, 704892.6369863 ,
#        268335.2739726 , 834705.65068493, 596398.28767123, 371805.47945205,
#        630480.99315068, 750245.71917808, 711953.59589041, 305948.45890411,
#        740469.00684932, 755541.43835616, 721866.09589041, 754862.5       ,
#        379816.95205479, 841902.39726027, 365287.67123288, 307306.33561644,
#        442550.85616438, 831989.89726027, 782020.03424658, 594225.68493151,
# ...

# %%
area_df['price'] = p
area_df
# Out:
#     area          price
# 0   2295  492249.143836
# 1   2323  496051.198630
# 2   3966  719150.342466
# 3   4111  738839.554795
# 4    699  275532.020548
# ..   ...            ...
# 95  3403  642701.883562
# 96   949  309478.938356
# 97  3898  709916.780822
# 98  3625  672846.746575
# 99  1316  359313.013699
#
# [100 rows x 2 columns]

# %% [markdown]
# # Machine Learning With Python: Linear Regression Multiple Values

# %% [markdown]
# ### Sample problem of predicting home price in monroe, new jersey (USA)

# %% [markdown]
# Below is the table containing home prices in moroe twp, NJ. Here price depends on area (square feet), bed rooms and age of the home (in years). Given these prices we have to predict prices of new homes based on area, bed rooms and age.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Given these home prices find out price of home that has:
# - 3000 sqr ft area, 3 bedrooms, 40 years old
# - 2500 sqr ft area, 4 bedrooms, 5 years old

# %%
import pandas as pd
import numpy as ny
from sklearn import linear_model

# %%
df = pd.read_csv('homeprices_2.csv')
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  500000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %% [markdown]
# Data Preprocessing: Fill NA values with median value of a column

# %%
df.bedrooms.median()
# Out:
# np.float64(4.0)

# %%
 df.bedrooms = df.bedrooms.fillna(df.bedrooms.median()) #Điền số median vào NaN
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  500000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg = linear_model.LinearRegression()
reg.fit(df.drop('price',axis = 'columns'), df.price)
# Out:
# LinearRegression()

# %%
X_train = df.drop('price', axis='columns')
X_train
# Out:
#    area  bedrooms  age
# 0  2600       3.0   20
# 1  3000       4.0   15
# 2  3200       4.0   18
# 3  3600       3.0   30
# 4  4000       5.0    8
# 5  4100       6.0    8

# %%
Y_train = df.price
Y_train
# Out:
# 0    500000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
reg.coef_
# Out:
# array([  127.76355439, 34308.29009674, -1894.21573736])

# %%
reg.intercept_
# Out:
# np.float64(91777.87343951827)

# %% [markdown]
# Find price of home with 3000 sqr ft area, 3 bedroóm, 40 years old

# %%
reg.predict([[3000,3,40]])
# Out:
# c:\Users\ad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([502224.77739765])
